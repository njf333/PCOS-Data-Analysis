# %%
Part A - Choosing a Data Set
The dataset I am choosing to work is PCOS dataset

PCOS = Polycystic Ovary Syndrome.

PCOS is one of the emerging diseases that is seen almost in every woman today due to our lifestyle, stress, anxiety, and malfunctioned food products. It is a complex condition where ovaries produce out of control androgens, i.e., male sex hormones which is present in women in usually small amount with no specific treatment or medication. When a woman is diagnosed with PCOS, it means that numerous small cysts have developed in the ovary hence disrupting normal ovary functions.

These days, women when diagnosed with PCOS, they do not share it with their family and it's a taboo disease that comes with a tag that a women cannot get pregnant when she is diagnosed with PCOS. PCOS is never discussed a lot and there is no proper medication to cure this condition. This condition results into high mood fluctuations, intense stress, weight gain, hair loss, acne, disrupted reproductive system, anxiety, skin patches, thyroid etc. 

I am specifically choosing this dataset as this condition is more serious than it is described, and it cannot be diagnosed at early stage as of now. It becomes very important to diagnose PCOS at early stage to avoid the misconceptions about the conditions and for the proper treatment.

PCOS are of 4 types:

1) Insulin Resistant - High level on insulin drives up androgen levels and can develop Diabetes
2) Adrenal PCOS - Excess Adrenal hormones causing infertility, most difficult to be diagnosed
3) Inflammatory PCOS - Excess testosterone resulting in ovulation issues
4) After pill PCOS - This occurs in some people after they stop taking oral contraceptive pills


Feature selection becomes the most crucial part here as there are thousands of features available in the dataset and no one of them guarantees the successful diagnosis of PCOS. Here I will be using 4 different Machine learning algorithms:

1)Decision Tree
2)Logistic Regression
3)KNN
4)Random Forest

Hence my reason for choosing this dataset is to further extend my analysis by diagnosing the type of PCOS a patient is suffering from, hence avoiding future complications. 

Currently, as per - the analysis is done only to detect PCOS. 

The next target would be to determine the type of PCOS from its symptoms to help patient take precautions accordingly.

Part B - Obtain Data
To proceed with our dataset, data needs to go through couple of steps here.
 
The data is downloaded from Kaggle, and the data is collected from 10 different hospitals in India. 

The data downloaded is already in the CSV (Comma separated value format). 

I am working on Anaconda Jupyter notebook. I downloaded Data from Kaggle which was already in .csv format and uploaded it to Jupyter notebook and assigned to 'data' variable to read CSV file in data frame. 

I have already cleaned my data in excel and dropped columns such as - Sr no, Patient file, BMI, Hip, Waist, Hip:Waist Ratio.
I cleaned up the extra space or any null values in excel itself.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix

#importing split training & Testing
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

#importing classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification

#importing report function
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
import sklearn.metrics as metrics

#reading of csv file to datafram
df = pd. read_csv('My_Dataset.csv') 

#Using head method to look for 1st few entries in the dataset and printing the data
df.head()
# Out:
#    PCOS (Y/N)  Age  Weight(kg)  Height(Cm)   Blood_Group  Pulse_Rate(bpm)   \
# 0           0   28        44.6        152.0           15                78
# 1           0   36        65.0        161.5           15                74
# 2           1   33        68.8        165.0           11                72
# 3           0   37        65.0        148.0           13                72
# 4           0   25        52.0        161.0           11                72
#
#    RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  Cycle_length(days)  ...  \
# 0                22     10.48           2                   5  ...
# 1                20     11.70           2                   5  ...
# 2                18     11.80           2                   5  ...
# 3                20     12.00           2                   5  ...
# 4                18     10.00           2                   5  ...
#
#    Pimples(Y/N)  Fast_food (Y/N)  Reg_Exercise(Y/N)  BP_Systolic (mmHg)  \
# ...

# %%
Part C - Scrubbing and Formatting

Data Analyzing becomes crucial step here to check for duplicates or missing values in the data. The data as of now contains 540 samples and 43 attributes.
Removing the Nan and infinite values:

# %%
#Displaying data with all features and the respective 5 rows
df.head().T
# Out:
#                            0      1       2      3       4
# PCOS (Y/N)                 0      0       1      0       0
# Age                       28     36      33     37      25
# Weight(kg)              44.6   65.0    68.8   65.0    52.0
# Height(Cm)             152.0  161.5   165.0  148.0   161.0
# Blood_Group               15     15      11     13      11
# Pulse_Rate(bpm)           78     74      72     72      72
# RR (breaths/min)          22     20      18     20      18
# Hb(g/dl)               10.48   11.7    11.8   12.0    10.0
# Cycle(R/I)                 2      2       2      2       2
# Cycle_length(days)         5      5       5      5       5
# Marriage_Status (Yrs)    7.0   11.0    10.0    4.0     1.0
# Pregnant(Y/N)              0      1       1      0       1
# No_of_aborptions           0      0       0      0       0
# I_beta-HCG(mIU/mL)      1.99   60.8  494.08   1.99  801.45
# II_beta-HCG(mIU/mL)     1.99   1.99  494.08   1.99  801.45
# ...

# %%
#Getting all the columns
col = df.columns
print(col)
# Out:
# Index(['PCOS (Y/N)', 'Age', 'Weight(kg)', 'Height(Cm) ', 'Blood_Group',
#        'Pulse_Rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)',
#        'Cycle_length(days)', 'Marriage_Status (Yrs)', 'Pregnant(Y/N)',
#        'No_of_aborptions', 'I_beta-HCG(mIU/mL)', 'II_beta-HCG(mIU/mL)',
#        'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit_D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight_gain(Y/N)', 'hair_growth(Y/N)',
#        'Skin_darkening (Y/N)', 'Hair_loss(Y/N)', 'Pimples(Y/N)',
#        'Fast_food (Y/N)', 'Reg_Exercise(Y/N)', 'BP_Systolic (mmHg)',
#        'BP_Diastolic (mmHg)', 'Follicle_No_(L)', 'Follicle_No_(R)',
#        'Avg_F siz_ (L) (mm)', 'Avg_F size_(R) (mm)', 'Endometrium_(mm)'],
#       dtype='object')

# %%
#Dropping PCOS(Y/N) as PCOS(Y/N) will be our deciding factor
drop_cols = ['PCOS (Y/N)', 'Marriage_Status (Yrs)','Height(Cm) ', 'Pulse_Rate(bpm) ', 'Hip(inch)', 'Waist(inch)']
X=df.drop(drop_cols, axis = 1)
Y = df["PCOS (Y/N)"]
print(col)
# Out:
# Index(['PCOS (Y/N)', 'Age', 'Weight(kg)', 'Height(Cm) ', 'Blood_Group',
#        'Pulse_Rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)',
#        'Cycle_length(days)', 'Marriage_Status (Yrs)', 'Pregnant(Y/N)',
#        'No_of_aborptions', 'I_beta-HCG(mIU/mL)', 'II_beta-HCG(mIU/mL)',
#        'FSH(mIU/mL)', 'LH(mIU/mL)', 'Hip(inch)', 'Waist(inch)', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit_D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight_gain(Y/N)', 'hair_growth(Y/N)',
#        'Skin_darkening (Y/N)', 'Hair_loss(Y/N)', 'Pimples(Y/N)',
#        'Fast_food (Y/N)', 'Reg_Exercise(Y/N)', 'BP_Systolic (mmHg)',
#        'BP_Diastolic (mmHg)', 'Follicle_No_(L)', 'Follicle_No_(R)',
#        'Avg_F siz_ (L) (mm)', 'Avg_F size_(R) (mm)', 'Endometrium_(mm)'],
#       dtype='object')

# %%
The features I have dropped here is 'Unnamed: 44', 'Marriage Status (Yrs.)',"PCOS (Y/N)",'FSH/LH', 'Sl. No', 'Patient File No.', 'BMI', 'Waist: Hip Ratio', 'Waist(inch)','Hip(inch)', 'Pulse rate(bpm) ', 'Height(Cm) '.
 
The reason I dropped these features is that it is not relevant to the PCOS. Here is the justification for each of them:

1)Unnamed 44: This was a null column and looks like it was entered by mistake, hence deleted that column
2)Marriage Status: PCOS condition can occur at any age irrespective of the fact that a girl is married or not.
3) PCOS(Y/N): This is a deciding factor, that is all the research about. This will be our output to that from the given symptoms.
4)FSH/LH: Follicle stimulating hormone and luteinizing hormone, I drooped this feature as we already have Follicle (L) and Follicle (R )
5) Sl. No:  I dropped this feature as this is not useful and contains only the serial no for the patient files.
6)Patient File No: I dropped this feature as this is not useful and contains only patient files.
6) BMI: Body Mass Index is not a deciding factor for PCOS. PCOS can happen to any woman at any age with any body weight.
7) Waist: Hip Ratio: This is again a irrelevant feature waist or hip size will not give us any insights about the PCOS.
8) Waist (inch): This is again a irrelevant feature waist size will not give us any insights about the PCOS.
9) Hip (size): This is again a irrelevant feature waist or hip size will not give us any insights about the PCOS.
10) 'Pulse rate(bpm): Pulse rate is not taken into consideration when a person is diagnosed with PCOS, it can happen to a person whose pulse rate is normal or abnormal.
11) 'Height (Cm): PCOS condition can again happen to any women with any height.

# %%
X
# Out:
#      Age  Weight(kg)  Blood_Group  RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  \
# 0     28        44.6           15                22     10.48           2
# 1     36        65.0           15                20     11.70           2
# 2     33        68.8           11                18     11.80           2
# 3     37        65.0           13                20     12.00           2
# 4     25        52.0           11                18     10.00           2
# ..   ...         ...          ...               ...       ...         ...
# 536   35        50.0           17                16     11.00           2
# 537   30        63.2           15                18     10.80           2
# 538   36        54.0           13                20     10.80           2
# 539   27        50.0           15                20     12.00           4
# 540   23        82.0           13                20     10.20           4
#
#      Cycle_length(days)  Pregnant(Y/N)  No_of_aborptions  I_beta-HCG(mIU/mL)  \
# ...

# %%
Part D - Exploratory Data Analysis
Using info () function, data type of the features is extracted. Here I have 541 instances and 33 features. Datatypes I have with my data is float64, int 64 and object.

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   541 non-null    int64
#  1   Weight(kg)            541 non-null    float64
#  2   Blood_Group           541 non-null    int64
#  3   RR (breaths/min)      541 non-null    int64
#  4   Hb(g/dl)              541 non-null    float64
#  5   Cycle(R/I)            541 non-null    int64
#  6   Cycle_length(days)    541 non-null    int64
#  7   Pregnant(Y/N)         541 non-null    int64
#  8   No_of_aborptions      541 non-null    int64
#  9   I_beta-HCG(mIU/mL)    541 non-null    float64
#  10  II_beta-HCG(mIU/mL)   541 non-null    object
#  11  FSH(mIU/mL)           541 non-null    float64
#  12  LH(mIU/mL)            541 non-null    float64
#  13  TSH (mIU/L)           541 non-null    float64
#  14  AMH(ng/mL)            541 non-null    object
# ...

# %%
Performing 5 number data for numeric data using describe () function

# %%
X.describe()
# Out:
#               Age  Weight(kg)  Blood_Group  RR (breaths/min)    Hb(g/dl)  \
# count  541.000000  541.000000   541.000000        541.000000  541.000000
# mean    31.430684   59.637153    13.802218         19.243993   11.160037
# std      5.411006   11.028287     1.840812          1.688629    0.866904
# min     20.000000   31.000000    11.000000         16.000000    8.500000
# 25%     28.000000   52.000000    13.000000         18.000000   10.500000
# 50%     31.000000   59.000000    14.000000         18.000000   11.000000
# 75%     35.000000   65.000000    15.000000         20.000000   11.700000
# max     48.000000  108.000000    18.000000         28.000000   14.800000
#
#        Cycle(R/I)  Cycle_length(days)  Pregnant(Y/N)  No_of_aborptions  \
# count  541.000000           541.00000     541.000000        541.000000
# mean     2.560074             4.94085       0.380776          0.288355
# std      0.901950             1.49202       0.486027          0.692575
# ...

# %%
Here are my findings when plotting features against each other (scatter). Here I am using seaborn library to plot features.

# %%
fig=sns.lmplot(data=df,x="Age",y="Cycle_length(days)", hue="PCOS (Y/N)")
plt.show(fig)

# %%
fig=sns.lmplot(data=df,x="Follicle_No_(L)",y="Follicle_No_(R)", hue="PCOS (Y/N)")
plt.show(fig)

# %%
fig=sns.lmplot(data=df,x="Follicle_No_(L)",y="Pimples(Y/N)", hue="PCOS (Y/N)")
plt.show(fig)

# %%
fig=sns.lmplot(data=df,x='hair_growth(Y/N)',y="Pimples(Y/N)", hue="PCOS (Y/N)")
plt.show(fig)

# %%
fig=sns.lmplot(data=df,x='Hair_loss(Y/N)',y="Follicle_No_(L)", hue="PCOS (Y/N)")
plt.show(fig)

# %%
sns.lmplot(data=df,x="Age",y="Cycle(R/I)", hue="PCOS (Y/N)")
plt.show()

# %%
features = ["Follicle_No_(L)","Follicle_No_(R)"]
for i in features:
    sns.swarmplot(x=df["PCOS (Y/N)"], y=df[i], color="black", alpha=0.5 )
    sns.boxenplot(x=df["PCOS (Y/N)"], y=df[i])
    plt.show()
# Out:
# C:\Users\joshi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 35.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\joshi\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
target = df['PCOS (Y/N)']
df.drop('PCOS (Y/N)',axis=1,inplace=True)

plt.figure(figsize=(7,6))
sns.countplot(target)
plt.title('Data imbalance')
plt.show()
# Out:
# C:\Users\joshi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Generating corelational matrix of the dataframe
corrmat = df.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap="Pastel1", square=True);

# %%
Part E - Report Initial Findings
 From the given graphs, I can conclude that I need to extract at least top 10 features out of 33 features that can predict PCOS precisely. I would be using Random Forest classifier to extract important features. I will be trying to use KNN, J48 and Naïve Bayes to extract the features and show the comparisons to get better understanding of the features and extract the best ones.

As per the results I got, I can conclude that AMH (ng/ml) is one of the very important features here. AMH - Anti-Müllerian hormone is a hormone that is produced in ovaries that is used to predict egg production frequency in ovaries. Also, Follicle(L) and Follicle ® are the important features here when combined with AMH (ng/ml), Follicles are small sacs filled with the fluid that contains immature egg. If the number of follicles is more, that can predict possible cystic ovaries hence giving promising results for PCOS.


Random Forest classification provides better results when the problem is related to classification. Here we need a decision about selection of the features that would precisely predict PCOS, and Random Forest here is a good choice as it builds up a decision tree and generates decision tree based on most of the votes taken from different samples.

Next, I want to implement is KNN (K-Nearest Neighbors), as it is very simple and easy to implement. KNN works on the idea of similarity.
